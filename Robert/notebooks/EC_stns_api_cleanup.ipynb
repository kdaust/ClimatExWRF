# %% [markdown]
# Station data acquired from api; see [csianglim/weather-gc-ca-python](https://github.com/csianglim/weather-gc-ca-python/blob/master/Part%20I%20-%20Data%20Extraction%20and%20Cleaning.ipynb)

# %%
import numpy as np
import xarray as xr
import pandas as pd
from glob import glob

import matplotlib.pyplot as plt
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %%
# Constants

FIRST_YEAR = 1990
LAST_YEAR = 2024
N_YEARS = LAST_YEAR - FIRST_YEAR + 1
N = 365 * 24 * N_YEARS + 6 * 24   # 24 extra hours for 6 leap years
COVERAGE_THRESHOLD = 0.9
ZSCORE_THRESHOLD = 4  # for outlier detection; may want to adjust (this seems to reject some plausible Wind Spd values, for instance)
vars = [
    "Temp (°C)",
    "Wind Spd (km/h)",
    "Stn Press (kPa)",
    "Rel Hum (%)",
    "Dew Point Temp (°C)",
]

# %%
# Takes ~3 minutes to run

wx_data_fnames = sorted(glob("/users/rpayne/data/unproc/STN_ECCC/api/hourly/*.csv"))
df = pd.concat(
    (pd.read_csv(f, encoding='latin1', low_memory=False) for f in wx_data_fnames),
    ignore_index=True
)
df['Date/Time (LST)'] = pd.to_datetime(df['Date/Time (LST)'], format='%Y-%m-%d %H:%M:%S')
df = df[df['Date/Time (LST)'].dt.year >= FIRST_YEAR]  # Filter for data after FIRST_YEAR
df = df[df['Date/Time (LST)'].dt.year <= LAST_YEAR]  # Filter for data before LAST_YEAR
df.set_index('Date/Time (LST)', inplace=True)
df.rename(columns={"Temp (Â°C)": "Temp (°C)"}, inplace=True)
df.rename(columns={"Dew Point Temp (Â°C)": "Dew Point Temp (°C)"}, inplace=True)
df
# Out:
#                      Longitude (x)  Latitude (y)   Station Name Climate ID  \
# Date/Time (LST)
# 2000-01-01 00:00:00        -119.44         49.03     OSOYOOS CS    1125852
# 2000-01-01 01:00:00        -119.44         49.03     OSOYOOS CS    1125852
# 2000-01-01 02:00:00        -119.44         49.03     OSOYOOS CS    1125852
# 2000-01-01 03:00:00        -119.44         49.03     OSOYOOS CS    1125852
# 2000-01-01 04:00:00        -119.44         49.03     OSOYOOS CS    1125852
# ...                            ...           ...            ...        ...
# 2023-12-31 19:00:00        -119.65         49.56  SUMMERLAND CS    112G8L1
# 2023-12-31 20:00:00        -119.65         49.56  SUMMERLAND CS    112G8L1
# 2023-12-31 21:00:00        -119.65         49.56  SUMMERLAND CS    112G8L1
# 2023-12-31 22:00:00        -119.65         49.56  SUMMERLAND CS    112G8L1
# 2023-12-31 23:00:00        -119.65         49.56  SUMMERLAND CS    112G8L1
#
#                      Year  Month  Day Time (LST) Flag  Temp (°C)  ...  \
# Date/Time (LST)                                                   ...
# 2000-01-01 00:00:00  2000      1    1      00:00  NaN       -0.4  ...
# 2000-01-01 01:00:00  2000      1    1      01:00  NaN       -0.2  ...
# 2000-01-01 02:00:00  2000      1    1      02:00  NaN       -0.2  ...
# 2000-01-01 03:00:00  2000      1    1      03:00  NaN       -0.2  ...
# 2000-01-01 04:00:00  2000      1    1      04:00  NaN       -0.5  ...
# ...                   ...    ...  ...        ...  ...        ...  ...
# 2023-12-31 19:00:00  2023     12   31      19:00  NaN        3.5  ...
# 2023-12-31 20:00:00  2023     12   31      20:00  NaN        3.4  ...
# 2023-12-31 21:00:00  2023     12   31      21:00  NaN        2.7  ...
# 2023-12-31 22:00:00  2023     12   31      22:00  NaN        2.2  ...
# 2023-12-31 23:00:00  2023     12   31      23:00  NaN        2.9  ...
#
#                     Visibility Flag  Stn Press (kPa) Stn Press Flag  Hmdx  \
# Date/Time (LST)
# 2000-01-01 00:00:00               M              NaN              M   NaN
# 2000-01-01 01:00:00               M              NaN              M   NaN
# 2000-01-01 02:00:00               M              NaN              M   NaN
# 2000-01-01 03:00:00               M              NaN              M   NaN
# 2000-01-01 04:00:00               M              NaN              M   NaN
# ...                             ...              ...            ...   ...
# 2023-12-31 19:00:00             NaN            96.90            NaN   NaN
# 2023-12-31 20:00:00             NaN            96.94            NaN   NaN
# 2023-12-31 21:00:00             NaN            96.94            NaN   NaN
# 2023-12-31 22:00:00             NaN            96.98            NaN   NaN
# 2023-12-31 23:00:00             NaN            97.01            NaN   NaN
#
#                     Hmdx Flag  Wind Chill Wind Chill Flag  Weather  \
# Date/Time (LST)
# 2000-01-01 00:00:00       NaN        -4.0             NaN      NaN
# 2000-01-01 01:00:00       NaN        -3.0             NaN      NaN
# 2000-01-01 02:00:00       NaN        -3.0             NaN      NaN
# 2000-01-01 03:00:00       NaN        -3.0             NaN      NaN
# 2000-01-01 04:00:00       NaN        -3.0             NaN      NaN
# ...                       ...         ...             ...      ...
# 2023-12-31 19:00:00       NaN         NaN             NaN      NaN
# 2023-12-31 20:00:00       NaN         NaN             NaN      NaN
# 2023-12-31 21:00:00       NaN         NaN             NaN      NaN
# 2023-12-31 22:00:00       NaN         NaN             NaN      NaN
# 2023-12-31 23:00:00       NaN         NaN             NaN      NaN
#
#                     Precip. Amount (mm)  Precip. Amount Flag
# Date/Time (LST)
# 2000-01-01 00:00:00                 NaN                  NaN
# 2000-01-01 01:00:00                 NaN                  NaN
# 2000-01-01 02:00:00                 NaN                  NaN
# 2000-01-01 03:00:00                 NaN                  NaN
# 2000-01-01 04:00:00                 NaN                  NaN
# ...                                 ...                  ...
# 2023-12-31 19:00:00                 0.0                  NaN
# 2023-12-31 20:00:00                 0.0                  NaN
# 2023-12-31 21:00:00                 0.0                  NaN
# 2023-12-31 22:00:00                 0.0                  NaN
# 2023-12-31 23:00:00                 0.0                  NaN
#
# [28261104 rows x 30 columns]

# %%
# Create a dictionary mapping station name to (lat, lon) from df
stn_latlon = {}
stns = df["Station Name"].unique()
for stn in stns:
    stn_rows = df[df["Station Name"] == stn]
    if not stn_rows.empty:
        lat = stn_rows["Latitude (y)"].iloc[0]
        lon = stn_rows["Longitude (x)"].iloc[0]
        stn_latlon[stn] = (lat, lon)
    else:
        stn_latlon[stn] = (None, None)


def get_stn(stn_name, data=df):
    stn = data[data["Station Name"] == stn_name]
    return stn.sort_index()

# %%
# Define a function that rejects any data with a z-score >= to some threshold.

def plot_data_dist(data, varname=None, lower_bound=-1e10, upper_bound=1e10):
    """
    Plots the distribution of the given data.
    """

    mu = data.mean()
    sigma = data.std(ddof=1)

    plt.figure(figsize=(4, 3))
    plt.hist(data, bins=30, edgecolor='black', alpha=0.7)
    if (mu + ZSCORE_THRESHOLD * sigma < upper_bound):
        plt.axvline(x=mu + ZSCORE_THRESHOLD * sigma, color='red', linestyle='--', lw=.5)
    if (mu - ZSCORE_THRESHOLD * sigma > lower_bound):
        plt.axvline(x=mu - ZSCORE_THRESHOLD * sigma, color='red', linestyle='--', lw=.5)
    plt.title('Distribution' if varname is None else f'Distribution of {varname}')
    plt.xlabel(f'{varname}' if varname else 'Data Values')
    plt.ylabel('Frequency')
    plt.grid(True, alpha=.2, linestyle='--')
    plt.show()

def reject_outliers(data, threshold=ZSCORE_THRESHOLD):
    """
    Rejects outliers in the data based on z-score threshold.
    """
    mu = data.mean()
    sigma = data.std(ddof=1)
    z_scores = (data - mu) / sigma
    return data.where(np.abs(z_scores) < threshold)

# %%
data = get_stn("COMOX A")
data_ws = data["Wind Spd (km/h)"]
data_pres = data["Stn Press (kPa)"]
data_temp = data["Temp (°C)"]
data_rh = data["Rel Hum (%)"]
plot_data_dist(data_ws, varname="Wind Speed (km/h)", lower_bound=0)
plot_data_dist(data_pres, varname="Station Pressure (kPa)")
plot_data_dist(data_temp, varname="Temperature (°C)")
plot_data_dist(data_rh, varname="Relative Humidity (%)", lower_bound=0, upper_bound=100)

# %%
# REMOVE OUTLIERS
for var in vars:
    df[var] = reject_outliers(df[var], threshold=ZSCORE_THRESHOLD)

# %%
# Find all stations that meet the coverage threshold for the given variable

WS_coverage_dict = {}
RH_coverage_dict = {}
P_coverage_dict = {}
T_coverage_dict = {}
Td_coverage_dict = {}

for i,stn in enumerate(stns):
    print(f"{i+1}/{len(stns)}")
    
    stn_data = get_stn(stn)

    WS_data = stn_data["Wind Spd (km/h)"]
    WS_coverage = np.count_nonzero(~np.isnan(WS_data)) / len(WS_data)
    if WS_coverage >= COVERAGE_THRESHOLD:
        WS_coverage_dict[stn] = WS_coverage

    RH_data = stn_data["Rel Hum (%)"]
    RH_coverage = np.count_nonzero(~np.isnan(RH_data)) / len(RH_data)
    if RH_coverage >= COVERAGE_THRESHOLD:
        RH_coverage_dict[stn] = RH_coverage

    T_data = stn_data["Temp (°C)"]
    T_coverage = np.count_nonzero(~np.isnan(T_data)) / len(T_data)
    if T_coverage >= COVERAGE_THRESHOLD:
        T_coverage_dict[stn] = T_coverage

    Td_data = stn_data["Dew Point Temp (°C)"]
    Td_coverage = np.count_nonzero(~np.isnan(Td_data)) / len(Td_data)
    if Td_coverage >= COVERAGE_THRESHOLD:
        Td_coverage_dict[stn] = Td_coverage

    P_data = stn_data["Stn Press (kPa)"]
    P_coverage = np.count_nonzero(~np.isnan(P_data)) / len(P_data)
    if P_coverage >= COVERAGE_THRESHOLD:
        P_coverage_dict[stn] = P_coverage
# Out:
# 1/203
# 2/203
# 3/203
# 4/203
# 5/203
# 6/203
# 7/203
# 8/203
# 9/203
# 10/203
# 11/203
# 12/203
# 13/203
# 14/203
# 15/203
# 16/203
# 17/203
# 18/203
# 19/203
# 20/203
# 21/203
# 22/203
# 23/203
# 24/203
# 25/203
# 26/203
# 27/203
# 28/203
# 29/203
# 30/203
# 31/203
# 32/203
# 33/203
# 34/203
# 35/203
# 36/203
# 37/203
# 38/203
# 39/203
# 40/203
# 41/203
# 42/203
# 43/203
# 44/203
# 45/203
# 46/203
# 47/203
# 48/203
# 49/203
# 50/203
# 51/203
# 52/203
# 53/203
# 54/203
# 55/203
# 56/203
# 57/203
# 58/203
# 59/203
# 60/203
# 61/203
# 62/203
# 63/203
# 64/203
# 65/203
# 66/203
# 67/203
# 68/203
# 69/203
# 70/203
# 71/203
# 72/203
# 73/203
# 74/203
# 75/203
# 76/203
# 77/203
# 78/203
# 79/203
# 80/203
# 81/203
# 82/203
# 83/203
# 84/203
# 85/203
# 86/203
# 87/203
# 88/203
# 89/203
# 90/203
# 91/203
# 92/203
# 93/203
# 94/203
# 95/203
# 96/203
# 97/203
# 98/203
# 99/203
# 100/203
# 101/203
# 102/203
# 103/203
# 104/203
# 105/203
# 106/203
# 107/203
# 108/203
# 109/203
# 110/203
# 111/203
# 112/203
# 113/203
# 114/203
# 115/203
# 116/203
# 117/203
# 118/203
# 119/203
# 120/203
# 121/203
# 122/203
# 123/203
# 124/203
# 125/203
# 126/203
# 127/203
# 128/203
# 129/203
# 130/203
# 131/203
# 132/203
# 133/203
# 134/203
# 135/203
# 136/203
# 137/203
# 138/203
# 139/203
# 140/203
# 141/203
# 142/203
# 143/203
# 144/203
# 145/203
# 146/203
# 147/203
# 148/203
# 149/203
# 150/203
# 151/203
# 152/203
# 153/203
# 154/203
# 155/203
# 156/203
# 157/203
# 158/203
# 159/203
# 160/203
# 161/203
# 162/203
# 163/203
# 164/203
# 165/203
# 166/203
# 167/203
# 168/203
# 169/203
# 170/203
# 171/203
# 172/203
# 173/203
# 174/203
# 175/203
# 176/203
# 177/203
# 178/203
# 179/203
# 180/203
# 181/203
# 182/203
# 183/203
# 184/203
# 185/203
# 186/203
# 187/203
# 188/203
# 189/203
# 190/203
# 191/203
# 192/203
# 193/203
# 194/203
# 195/203
# 196/203
# 197/203
# 198/203
# 199/203
# 200/203
# 201/203
# 202/203
# 203/203

# %%
q_stns_A = set(RH_coverage_dict.keys()) & set(T_coverage_dict.keys()) & set(P_coverage_dict.keys())
q_stns_B = set(Td_coverage_dict.keys()) & set(P_coverage_dict.keys())
q_stns_C = set(RH_coverage_dict.keys()) & set(T_coverage_dict.keys())
print(f"Number of stations with adequate Wind Speed coverage: {len(WS_coverage_dict)}")
print(f"Number of stations with adequate (RH, T, and P) coverage: {len(q_stns_A)}")
print(f"Number of stations with adequate (Td and P) coverage: {len(q_stns_B)}")
print(f"Number of stations with both adequate (RH, T, P) and (Td, P) coverage: {len(q_stns_A & q_stns_B)}")
print(f"Number of stations with adequate (RH and T) coverage: {len(q_stns_C)}")

q_stns_A = list(q_stns_A)
q_stns_B = list(q_stns_B)
q_stns_C = list(q_stns_C)
# Out:
# Number of stations with adequate Wind Speed coverage: 89
# Number of stations with adequate (RH, T, and P) coverage: 66
# Number of stations with adequate (Td and P) coverage: 66
# Number of stations with both adequate (RH, T, P) and (Td, P) coverage: 65
# Number of stations with adequate (RH and T) coverage: 76

# %%
topography_hr = xr.open_dataset("/users/rpayne/data/topography/hr/HGT_orig.nc")
lon = topography_hr['XLONG'].squeeze()
lat = topography_hr['XLAT'].squeeze()
hgt = topography_hr['HGT'].squeeze()

# Create a figure
fig, ax = plt.subplots(subplot_kw={"projection": ccrs.PlateCarree()},figsize=(4,2),dpi=200)

# Plot using pcolormesh
mesh = ax.pcolormesh(lon, lat, hgt, transform=ccrs.PlateCarree(), shading='auto')
ax.add_feature(cfeature.BORDERS, linewidth=1)   # Country borders
provinc_bodr = cartopy.feature.NaturalEarthFeature(category='cultural', 
    name='admin_1_states_provinces_lines', scale='50m', facecolor='none', edgecolor='k')
ax.add_feature(provinc_bodr, linestyle='--', linewidth=0.6, edgecolor="k", zorder=10)
for stn in WS_coverage_dict.keys():
    lat, lon = stn_latlon[stn]
    ax.plot(lon, lat, marker='o', color='red', markersize=.8, transform=ccrs.PlateCarree())
ax.set_xlim(-134, -114)
ax.set_ylim(48, 62)
ax.text(-119.4, 60.5, f"N={len(WS_coverage_dict.keys())}", fontsize=12, transform=ccrs.PlateCarree(), color='red')

# Add coastlines and colorbar
ax.coastlines(linewidth=0.5)

ax.set_title(f"Stations: >{100*COVERAGE_THRESHOLD:.0f}% Wind Spd. Coverage", fontsize=10)
plt.show()

# %%
topography_hr = xr.open_dataset("/users/rpayne/data/topography/hr/HGT_orig.nc")
lon = topography_hr['XLONG'].squeeze()
lat = topography_hr['XLAT'].squeeze()
hgt = topography_hr['HGT'].squeeze()

# Create a figure
fig, ax = plt.subplots(subplot_kw={"projection": ccrs.PlateCarree()},figsize=(4,2),dpi=200)

# Plot using pcolormesh
mesh = ax.pcolormesh(lon, lat, hgt, transform=ccrs.PlateCarree(), shading='auto')
ax.add_feature(cfeature.BORDERS, linewidth=1)   # Country borders
provinc_bodr = cartopy.feature.NaturalEarthFeature(category='cultural', 
    name='admin_1_states_provinces_lines', scale='50m', facecolor='none', edgecolor='k')
ax.add_feature(provinc_bodr, linestyle='--', linewidth=0.6, edgecolor="k", zorder=10)
for stn in q_stns_A:
    lat, lon = stn_latlon[stn]
    ax.plot(lon, lat, marker='o', color='red', markersize=.8, transform=ccrs.PlateCarree())
ax.set_xlim(-134, -114)
ax.set_ylim(48, 62)
ax.text(-119.4, 60.5, f"N={len(q_stns_A)}", fontsize=12, transform=ccrs.PlateCarree(), color='red')

# Add coastlines and colorbar
ax.coastlines(linewidth=0.5)

ax.set_title(f"Stations: >{100*COVERAGE_THRESHOLD:.0f}% Sp. Humid. Coverage", fontsize=10)
plt.show()

# %%
topography_hr = xr.open_dataset("/users/rpayne/data/topography/hr/HGT_orig.nc")
lon = topography_hr['XLONG'].squeeze()
lat = topography_hr['XLAT'].squeeze()
hgt = topography_hr['HGT'].squeeze()

# Create a figure
fig, ax = plt.subplots(subplot_kw={"projection": ccrs.PlateCarree()},figsize=(4,2),dpi=200)

# Plot using pcolormesh
mesh = ax.pcolormesh(lon, lat, hgt, transform=ccrs.PlateCarree(), shading='auto')
ax.add_feature(cfeature.BORDERS, linewidth=1)   # Country borders
provinc_bodr = cartopy.feature.NaturalEarthFeature(category='cultural', 
    name='admin_1_states_provinces_lines', scale='50m', facecolor='none', edgecolor='k')
ax.add_feature(provinc_bodr, linestyle='--', linewidth=0.6, edgecolor="k", zorder=10)
for stn in q_stns_C:
    lat, lon = stn_latlon[stn]
    ax.plot(lon, lat, marker='o', color='red', markersize=.8, transform=ccrs.PlateCarree())
ax.set_xlim(-134, -114)
ax.set_ylim(48, 62)
ax.text(-119.4, 60.5, f"N={len(q_stns_C)}", fontsize=12, transform=ccrs.PlateCarree(), color='red')

# Add coastlines and colorbar
ax.coastlines(linewidth=0.5)

ax.set_title(f"Stations: >{100*COVERAGE_THRESHOLD:.0f}% RH and T Coverage", fontsize=10)
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.yticks(np.arange(len(q_stns_A)), sorted(q_stns_A, reverse=True), fontsize=6)
plt.ylim(-1, len(q_stns_A))
plt.xticks(
    ticks=pd.date_range(start='1990-01-01', end='2026-01-01', freq='2YS'),
    labels=[str(y.year) for y in pd.date_range(start='1990-01-01', end='2026-01-01', freq='2YS')],
    rotation=45,
    fontsize=8
)
colors = ["navy", "dodgerblue", "darkorange"]

di = .22
lw = 3.75
for i,stn in enumerate(sorted(q_stns_A, reverse=True)):
    print(f"Plotting for {stn} ({i+1}/{len(q_stns_A)})")

    stn_data = get_stn(stn)
    rh = stn_data["Rel Hum (%)"]
    pres = stn_data["Stn Press (kPa)"]
    temp = stn_data["Temp (°C)"]
    rh = rh.where(rh.isna(), i+di)
    pres = pres.where(pres.isna(), i)
    temp = temp.where(temp.isna(), i-di)

    plt.axhline(y=i, color='black', linewidth=0.5, linestyle='--', alpha=0.4)
    plt.axhline(y=i+di, color='black', linewidth=0.5, linestyle='--', alpha=0.4)
    plt.axhline(y=i-di, color='black', linewidth=0.5, linestyle='--', alpha=0.4)
    if i == 0:
        plt.plot(rh.index, rh, drawstyle='steps-post', linewidth=lw, color=colors[0], label='Relative Humidity')
        plt.plot(pres.index, pres, drawstyle='steps-post', linewidth=lw, color=colors[1], label='Station Pressure')
        plt.plot(temp.index, temp, drawstyle='steps-post', linewidth=lw, color=colors[2], label='Temperature')
    else:
        plt.plot(rh.index, rh, drawstyle='steps-post', linewidth=lw, color=colors[0])
        plt.plot(pres.index, pres, drawstyle='steps-post', linewidth=lw, color=colors[1])
        plt.plot(temp.index, temp, drawstyle='steps-post', linewidth=lw, color=colors[2])

plt.legend(loc='upper left', fontsize=8, ncol=3, bbox_to_anchor=(0.45, 1.04), frameon=False)
# plt.tight_layout()
plt.show()
# Out:
# Plotting for WILLIAMS LAKE A (1/66)
# Plotting for WHITE ROCK CAMPBELL SCIENTIFIC (2/66)
# Plotting for WHISTLER - NESTERS (3/66)
# Plotting for WEST VANCOUVER AUT (4/66)
# Plotting for VICTORIA INTL A (5/66)
# Plotting for VICTORIA INT'L A (6/66)
# Plotting for VERNON AUTO (7/66)
# Plotting for VANCOUVER SEA ISLAND CCG (8/66)
# Plotting for VANCOUVER INTL A (9/66)
# Plotting for VANCOUVER INT'L A (10/66)
# Plotting for TERRACE A (11/66)
# Plotting for SUMMERLAND CS (12/66)
# Plotting for SMITHERS AIRPORT AUTO (13/66)
# Plotting for SMITHERS (14/66)
# Plotting for SECHELT AUT (15/66)
# Plotting for SATURNA ISLAND CS (16/66)
# Plotting for SATURNA CAPMON CS (17/66)
# Plotting for SANDSPIT AIRPORT AUTO (18/66)
# Plotting for SANDSPIT (19/66)
# Plotting for SALMON ARM CS (20/66)
# Plotting for QUESNEL AIRPORT AUTO (21/66)
# Plotting for QUESNEL (22/66)
# Plotting for QUALICUM BEACH AIRPORT (23/66)
# Plotting for PRINCETON CS (24/66)
# Plotting for PRINCE RUPERT (25/66)
# Plotting for PRINCE GEORGE MASSEY AUTO (26/66)
# Plotting for PRINCE GEORGE AIRPORT AUTO (27/66)
# Plotting for PRINCE GEORGE A (28/66)
# Plotting for POWELL RIVER (29/66)
# Plotting for PORT MELLON (30/66)
# Plotting for PORT HARDY A (31/66)
# Plotting for PORT ALBERNI (AUT) (32/66)
# Plotting for PITT MEADOWS CS (33/66)
# Plotting for PENTICTON A (34/66)
# Plotting for OSOYOOS CS (35/66)
# Plotting for OOTSA LAKESKINS LAKE CLIMATE (36/66)
# Plotting for NORTH COWICHAN (37/66)
# Plotting for NELSON CS (38/66)
# Plotting for NAKUSP CS (39/66)
# Plotting for MACKENZIE AIRPORT AUTO (40/66)
# Plotting for MACKENZIE (41/66)
# Plotting for LYTTON A (42/66)
# Plotting for LYTTON (43/66)
# Plotting for KELOWNA UBCO (44/66)
# Plotting for KELOWNA (45/66)
# Plotting for KAMLOOPS AUT (46/66)
# Plotting for KAMLOOPS A (47/66)
# Plotting for HOPE AIRPORT (48/66)
# Plotting for HOPE A (49/66)
# Plotting for FORT ST. JOHN A (50/66)
# Plotting for FORT ST JOHN A (51/66)
# Plotting for FORT ST JAMES AUTO (52/66)
# Plotting for FORT NELSON A (53/66)
# Plotting for CRESTON CAMPBELL SCIENTIFIC (54/66)
# Plotting for CRANBROOK AIRPORT AUTO (55/66)
# Plotting for CRANBROOK A (56/66)
# Plotting for COMOX A (57/66)
# Plotting for CLINTON RCS (58/66)
# Plotting for CLINTON A (59/66)
# Plotting for CLEARWATER AUTO (60/66)
# Plotting for CALLAGHAN VALLEY (61/66)
# Plotting for BURNS LAKE DECKER LAKE (62/66)
# Plotting for BLUE RIVER CS (63/66)
# Plotting for BELLA BELLA (64/66)
# Plotting for AGASSIZ RCS (65/66)
# Plotting for ABBOTSFORD A (66/66)

# %%
plt.figure(figsize=(10, 8))
plt.yticks(np.arange(len(q_stns_A)), sorted(q_stns_A, reverse=True), fontsize=6)
plt.ylim(-1, len(q_stns_A))
plt.xticks(
    ticks=pd.date_range(start='1990-01-01', end='2026-01-01', freq='2YS'),
    labels=[str(y.year) for y in pd.date_range(start='1990-01-01', end='2026-01-01', freq='2YS')],
    rotation=45,
    fontsize=8
)
colors = ["navy", "dodgerblue", "darkorange"]

di = .15
lw = 3.75
for i,stn in enumerate(sorted(q_stns_A, reverse=True)):
    print(f"Plotting for {stn} ({i+1}/{len(q_stns_A)})")

    stn_data = get_stn(stn)
    pres = stn_data["Stn Press (kPa)"]
    dewtemp = stn_data["Dew Point Temp (°C)"]
    pres = pres.where(pres.isna(), i+di)
    dewtemp = dewtemp.where(dewtemp.isna(), i-di)

    plt.axhline(y=i+di, color='black', linewidth=0.5, linestyle='--', alpha=0.4)
    plt.axhline(y=i-di, color='black', linewidth=0.5, linestyle='--', alpha=0.4)
    if i == 0:
        plt.plot(pres.index, pres, drawstyle='steps-post', linewidth=lw, color=colors[0], label='Station Pressure')
        plt.plot(dewtemp.index, dewtemp, drawstyle='steps-post', linewidth=lw, color=colors[2], label='Dew Point')
    else:
        plt.plot(pres.index, pres, drawstyle='steps-post', linewidth=lw, color=colors[0])
        plt.plot(dewtemp.index, dewtemp, drawstyle='steps-post', linewidth=lw, color=colors[2])

plt.legend(loc='upper left', fontsize=8, ncol=3, bbox_to_anchor=(0.65, 1.04), frameon=False)
# plt.tight_layout()
plt.show()
# Out:
# Plotting for WILLIAMS LAKE A (1/66)
# Plotting for WHITE ROCK CAMPBELL SCIENTIFIC (2/66)
# Plotting for WHISTLER - NESTERS (3/66)
# Plotting for WEST VANCOUVER AUT (4/66)
# Plotting for VICTORIA INTL A (5/66)
# Plotting for VICTORIA INT'L A (6/66)
# Plotting for VERNON AUTO (7/66)
# Plotting for VANCOUVER SEA ISLAND CCG (8/66)
# Plotting for VANCOUVER INTL A (9/66)
# Plotting for VANCOUVER INT'L A (10/66)
# Plotting for TERRACE A (11/66)
# Plotting for SUMMERLAND CS (12/66)
# Plotting for SMITHERS AIRPORT AUTO (13/66)
# Plotting for SMITHERS (14/66)
# Plotting for SECHELT AUT (15/66)
# Plotting for SATURNA ISLAND CS (16/66)
# Plotting for SATURNA CAPMON CS (17/66)
# Plotting for SANDSPIT AIRPORT AUTO (18/66)
# Plotting for SANDSPIT (19/66)
# Plotting for SALMON ARM CS (20/66)
# Plotting for QUESNEL AIRPORT AUTO (21/66)
# Plotting for QUESNEL (22/66)
# Plotting for QUALICUM BEACH AIRPORT (23/66)
# Plotting for PRINCETON CS (24/66)
# Plotting for PRINCE RUPERT (25/66)
# Plotting for PRINCE GEORGE MASSEY AUTO (26/66)
# Plotting for PRINCE GEORGE AIRPORT AUTO (27/66)
# Plotting for PRINCE GEORGE A (28/66)
# Plotting for POWELL RIVER (29/66)
# Plotting for PORT MELLON (30/66)
# Plotting for PORT HARDY A (31/66)
# Plotting for PORT ALBERNI (AUT) (32/66)
# Plotting for PITT MEADOWS CS (33/66)
# Plotting for PENTICTON A (34/66)
# Plotting for OSOYOOS CS (35/66)
# Plotting for OOTSA LAKESKINS LAKE CLIMATE (36/66)
# Plotting for NORTH COWICHAN (37/66)
# Plotting for NELSON CS (38/66)
# Plotting for NAKUSP CS (39/66)
# Plotting for MACKENZIE AIRPORT AUTO (40/66)
# Plotting for MACKENZIE (41/66)
# Plotting for LYTTON A (42/66)
# Plotting for LYTTON (43/66)
# Plotting for KELOWNA UBCO (44/66)
# Plotting for KELOWNA (45/66)
# Plotting for KAMLOOPS AUT (46/66)
# Plotting for KAMLOOPS A (47/66)
# Plotting for HOPE AIRPORT (48/66)
# Plotting for HOPE A (49/66)
# Plotting for FORT ST. JOHN A (50/66)
# Plotting for FORT ST JOHN A (51/66)
# Plotting for FORT ST JAMES AUTO (52/66)
# Plotting for FORT NELSON A (53/66)
# Plotting for CRESTON CAMPBELL SCIENTIFIC (54/66)
# Plotting for CRANBROOK AIRPORT AUTO (55/66)
# Plotting for CRANBROOK A (56/66)
# Plotting for COMOX A (57/66)
# Plotting for CLINTON RCS (58/66)
# Plotting for CLINTON A (59/66)
# Plotting for CLEARWATER AUTO (60/66)
# Plotting for CALLAGHAN VALLEY (61/66)
# Plotting for BURNS LAKE DECKER LAKE (62/66)
# Plotting for BLUE RIVER CS (63/66)
# Plotting for BELLA BELLA (64/66)
# Plotting for AGASSIZ RCS (65/66)
# Plotting for ABBOTSFORD A (66/66)

# %%
plt.figure(figsize=(10, 8))
plt.yticks(np.arange(len(Td_coverage_dict.keys())), sorted(list(Td_coverage_dict.keys()), reverse=True), fontsize=6)
plt.ylim(-1, len(Td_coverage_dict.keys()))
plt.xticks(
    ticks=pd.date_range(start='1990-01-01', end='2026-01-01', freq='2YS'),
    labels=[str(y.year) for y in pd.date_range(start='1990-01-01', end='2026-01-01', freq='2YS')],
    rotation=45,
    fontsize=8
)
color = ["navy", "darkorange"]

var = "Dew Point Temp (°C)"
for i,stn in enumerate(sorted(list(Td_coverage_dict.keys()), reverse=True)):
    print(f"Plotting {var} for {stn} ({i+1}/{len(Td_coverage_dict.keys())})")
    data = get_stn(stn)[var]
    data = data.where(data.isna(), i)
    plt.axhline(y=i, color='black', linewidth=0.5, linestyle='--', alpha=0.4)
    data.plot(ax=plt.gca(), label=stn, drawstyle='steps-post', linewidth=4, color='navy')

plt.title(f"{var}", fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# Plotting Dew Point Temp (°C) for WILLIAMS LAKE A (1/76)
# Plotting Dew Point Temp (°C) for WHITE ROCK CAMPBELL SCIENTIFIC (2/76)
# /users/rpayne/venv/wx-to-fwi/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:981: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   return ax.plot(*args, **kwds)
# Plotting Dew Point Temp (°C) for WHISTLER - NESTERS (3/76)
# Plotting Dew Point Temp (°C) for WEST VANCOUVER AUT (4/76)
# Plotting Dew Point Temp (°C) for VICTORIA UNIVERSITY CS (5/76)
# Plotting Dew Point Temp (°C) for VICTORIA INTL A (6/76)
# Plotting Dew Point Temp (°C) for VICTORIA INT'L A (7/76)
# Plotting Dew Point Temp (°C) for VICTORIA HARTLAND CS (8/76)
# Plotting Dew Point Temp (°C) for VICTORIA GONZALES CS (9/76)
# Plotting Dew Point Temp (°C) for VERNON AUTO (10/76)
# Plotting Dew Point Temp (°C) for VANCOUVER SEA ISLAND CCG (11/76)
# Plotting Dew Point Temp (°C) for VANCOUVER INTL A (12/76)
# Plotting Dew Point Temp (°C) for VANCOUVER INT'L A (13/76)
# Plotting Dew Point Temp (°C) for TERRACE A (14/76)
# Plotting Dew Point Temp (°C) for TATLAYOKO LAKE RCS (15/76)
# Plotting Dew Point Temp (°C) for SUMMERLAND CS (16/76)
# Plotting Dew Point Temp (°C) for SMITHERS AIRPORT AUTO (17/76)
# Plotting Dew Point Temp (°C) for SMITHERS (18/76)
# Plotting Dew Point Temp (°C) for SISTERS ISLAND (19/76)
# Plotting Dew Point Temp (°C) for SECHELT AUT (20/76)
# Plotting Dew Point Temp (°C) for SATURNA ISLAND CS (21/76)
# Plotting Dew Point Temp (°C) for SANDSPIT AIRPORT AUTO (22/76)
# Plotting Dew Point Temp (°C) for SANDSPIT (23/76)
# Plotting Dew Point Temp (°C) for SALMON ARM CS (24/76)
# Plotting Dew Point Temp (°C) for QUESNEL AIRPORT AUTO (25/76)
# Plotting Dew Point Temp (°C) for QUESNEL (26/76)
# Plotting Dew Point Temp (°C) for QUALICUM BEACH AIRPORT (27/76)
# Plotting Dew Point Temp (°C) for PUNTZI MOUNTAIN (AUT) (28/76)
# Plotting Dew Point Temp (°C) for PRINCETON CS (29/76)
# Plotting Dew Point Temp (°C) for PRINCE RUPERT (30/76)
# Plotting Dew Point Temp (°C) for PRINCE GEORGE MASSEY AUTO (31/76)
# Plotting Dew Point Temp (°C) for PRINCE GEORGE AIRPORT AUTO (32/76)
# Plotting Dew Point Temp (°C) for PRINCE GEORGE A (33/76)
# Plotting Dew Point Temp (°C) for PRINCE GEORGE (34/76)
# Plotting Dew Point Temp (°C) for POWELL RIVER (35/76)
# Plotting Dew Point Temp (°C) for PORT MELLON (36/76)
# Plotting Dew Point Temp (°C) for PORT HARDY A (37/76)
# Plotting Dew Point Temp (°C) for PORT ALBERNI (AUT) (38/76)
# Plotting Dew Point Temp (°C) for PITT MEADOWS CS (39/76)
# Plotting Dew Point Temp (°C) for PENTICTON A (40/76)
# Plotting Dew Point Temp (°C) for PEMBERTON AIRPORT CS (41/76)
# Plotting Dew Point Temp (°C) for OSOYOOS CS (42/76)
# Plotting Dew Point Temp (°C) for OOTSA LAKESKINS LAKE CLIMATE (43/76)
# Plotting Dew Point Temp (°C) for NORTH COWICHAN (44/76)
# Plotting Dew Point Temp (°C) for NELSON CS (45/76)
# Plotting Dew Point Temp (°C) for NAKUSP CS (46/76)
# Plotting Dew Point Temp (°C) for MERRITT (47/76)
# Plotting Dew Point Temp (°C) for MACKENZIE AIRPORT AUTO (48/76)
# Plotting Dew Point Temp (°C) for MACKENZIE (49/76)
# Plotting Dew Point Temp (°C) for LYTTON A (50/76)
# Plotting Dew Point Temp (°C) for LYTTON (51/76)
# Plotting Dew Point Temp (°C) for KELOWNA UBCO (52/76)
# Plotting Dew Point Temp (°C) for KELOWNA (53/76)
# Plotting Dew Point Temp (°C) for KAMLOOPS AUT (54/76)
# Plotting Dew Point Temp (°C) for KAMLOOPS A (55/76)
# Plotting Dew Point Temp (°C) for HOPE AIRPORT (56/76)
# Plotting Dew Point Temp (°C) for HOPE A (57/76)
# Plotting Dew Point Temp (°C) for FORT ST. JOHN A (58/76)
# Plotting Dew Point Temp (°C) for FORT ST JOHN A (59/76)
# Plotting Dew Point Temp (°C) for FORT ST JAMES AUTO (60/76)
# Plotting Dew Point Temp (°C) for FORT NELSON A (61/76)
# Plotting Dew Point Temp (°C) for ESQUIMALT HARBOUR (62/76)
# Plotting Dew Point Temp (°C) for CULTUS LAKE (63/76)
# Plotting Dew Point Temp (°C) for CRESTON CAMPBELL SCIENTIFIC (64/76)
# Plotting Dew Point Temp (°C) for CRANBROOK AIRPORT AUTO (65/76)
# Plotting Dew Point Temp (°C) for CRANBROOK A (66/76)
# Plotting Dew Point Temp (°C) for COMOX A (67/76)
# Plotting Dew Point Temp (°C) for CLINTON RCS (68/76)
# Plotting Dew Point Temp (°C) for CLINTON A (69/76)
# Plotting Dew Point Temp (°C) for CLEARWATER AUTO (70/76)
# Plotting Dew Point Temp (°C) for CALLAGHAN VALLEY (71/76)
# Plotting Dew Point Temp (°C) for BURNS LAKE DECKER LAKE (72/76)
# Plotting Dew Point Temp (°C) for BLUE RIVER CS (73/76)
# Plotting Dew Point Temp (°C) for BELLA BELLA (74/76)
# Plotting Dew Point Temp (°C) for AGASSIZ RCS (75/76)
# Plotting Dew Point Temp (°C) for ABBOTSFORD A (76/76)

# %%
plt.figure(figsize=(10, 8))
plt.yticks(np.arange(len(WS_coverage_dict.keys())), sorted(list(WS_coverage_dict.keys()), reverse=True), fontsize=6)
plt.ylim(-1, len(WS_coverage_dict.keys()))
plt.xticks(
    ticks=pd.date_range(start='1990-01-01', end='2026-01-01', freq='2YS'),
    labels=[str(y.year) for y in pd.date_range(start='1990-01-01', end='2026-01-01', freq='2YS')],
    rotation=45,
    fontsize=8
)
color = ["navy", "darkorange"]

var = "Wind Spd (km/h)"
for i,stn in enumerate(sorted(list(WS_coverage_dict.keys()), reverse=True)):
    print(f"Plotting {var} for {stn} ({i+1}/{len(WS_coverage_dict.keys())})")
    data = get_stn(stn)[var]
    data = data.where(data.isna(), i)
    plt.axhline(y=i, color='black', linewidth=0.5, linestyle='--', alpha=0.4)
    data.plot(ax=plt.gca(), label=stn, drawstyle='steps-post', linewidth=4, color="navy")

plt.title(f"{var}", fontsize=10)
plt.tight_layout()
plt.show()
# Out:
# Plotting Wind Spd (km/h) for WILLIAMS LAKE A (1/89)
# Plotting Wind Spd (km/h) for WHITE ROCK CAMPBELL SCIENTIFIC (2/89)
# /users/rpayne/venv/wx-to-fwi/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:981: UserWarning: This axis already has a converter set and is updating to a potentially incompatible converter
#   return ax.plot(*args, **kwds)
# Plotting Wind Spd (km/h) for WEST VANCOUVER AUT (3/89)
# Plotting Wind Spd (km/h) for WARFIELD RCS (4/89)
# Plotting Wind Spd (km/h) for VICTORIA UNIVERSITY CS (5/89)
# Plotting Wind Spd (km/h) for VICTORIA INTL A (6/89)
# Plotting Wind Spd (km/h) for VICTORIA INT'L A (7/89)
# Plotting Wind Spd (km/h) for VICTORIA HARTLAND CS (8/89)
# Plotting Wind Spd (km/h) for VICTORIA GONZALES CS (9/89)
# Plotting Wind Spd (km/h) for VERNON AUTO (10/89)
# Plotting Wind Spd (km/h) for VANCOUVER SEA ISLAND CCG (11/89)
# Plotting Wind Spd (km/h) for VANCOUVER INTL A (12/89)
# Plotting Wind Spd (km/h) for VANCOUVER INT'L A (13/89)
# Plotting Wind Spd (km/h) for TSAWWASSEN FERRY AUTO (14/89)
# Plotting Wind Spd (km/h) for TERRACE A (15/89)
# Plotting Wind Spd (km/h) for SUMMERLAND CS (16/89)
# Plotting Wind Spd (km/h) for SMITHERS AIRPORT AUTO (17/89)
# Plotting Wind Spd (km/h) for SMITHERS (18/89)
# Plotting Wind Spd (km/h) for SISTERS ISLAND (19/89)
# Plotting Wind Spd (km/h) for SHERINGHAM POINT (20/89)
# Plotting Wind Spd (km/h) for SECHELT AUT (21/89)
# Plotting Wind Spd (km/h) for SATURNA ISLAND CS (22/89)
# Plotting Wind Spd (km/h) for SATURNA CAPMON CS (23/89)
# Plotting Wind Spd (km/h) for SANDSPIT AIRPORT AUTO (24/89)
# Plotting Wind Spd (km/h) for SANDSPIT (25/89)
# Plotting Wind Spd (km/h) for SANDHEADS CS (26/89)
# Plotting Wind Spd (km/h) for SALMON ARM CS (27/89)
# Plotting Wind Spd (km/h) for RACE ROCKS (28/89)
# Plotting Wind Spd (km/h) for QUESNEL AIRPORT AUTO (29/89)
# Plotting Wind Spd (km/h) for QUESNEL (30/89)
# Plotting Wind Spd (km/h) for QUALICUM BEACH AIRPORT (31/89)
# Plotting Wind Spd (km/h) for PUNTZI MOUNTAIN (AUT) (32/89)
# Plotting Wind Spd (km/h) for PRINCETON CS (33/89)
# Plotting Wind Spd (km/h) for PRINCE RUPERT (34/89)
# Plotting Wind Spd (km/h) for PRINCE GEORGE MASSEY AUTO (35/89)
# Plotting Wind Spd (km/h) for PRINCE GEORGE AIRPORT AUTO (36/89)
# Plotting Wind Spd (km/h) for PRINCE GEORGE A (37/89)
# Plotting Wind Spd (km/h) for PRINCE GEORGE (38/89)
# Plotting Wind Spd (km/h) for PORT MELLON (39/89)
# Plotting Wind Spd (km/h) for PORT HARDY A (40/89)
# Plotting Wind Spd (km/h) for PORT ALBERNI (AUT) (41/89)
# Plotting Wind Spd (km/h) for POINT ATKINSON (42/89)
# Plotting Wind Spd (km/h) for PITT MEADOWS CS (43/89)
# Plotting Wind Spd (km/h) for PENTICTON A (44/89)
# Plotting Wind Spd (km/h) for PEMBERTON AIRPORT (WIND) (45/89)
# Plotting Wind Spd (km/h) for OSOYOOS CS (46/89)
# Plotting Wind Spd (km/h) for OOTSA LAKESKINS LAKE CLIMATE (47/89)
# Plotting Wind Spd (km/h) for NORTH COWICHAN (48/89)
# Plotting Wind Spd (km/h) for NAKUSP CS (49/89)
# Plotting Wind Spd (km/h) for MERRITT (50/89)
# Plotting Wind Spd (km/h) for MACKENZIE AIRPORT AUTO (51/89)
# Plotting Wind Spd (km/h) for MACKENZIE (52/89)
# Plotting Wind Spd (km/h) for LYTTON A (53/89)
# Plotting Wind Spd (km/h) for LYTTON (54/89)
# Plotting Wind Spd (km/h) for KELP REEFS (55/89)
# Plotting Wind Spd (km/h) for KELOWNA (56/89)
# Plotting Wind Spd (km/h) for KAMLOOPS AUT (57/89)
# Plotting Wind Spd (km/h) for KAMLOOPS A (58/89)
# Plotting Wind Spd (km/h) for HOWE SOUND - PAM ROCKS (59/89)
# Plotting Wind Spd (km/h) for HOPE AIRPORT (60/89)
# Plotting Wind Spd (km/h) for HOPE A (61/89)
# Plotting Wind Spd (km/h) for HOLLAND ROCK (62/89)
# Plotting Wind Spd (km/h) for GRIEF POINT (63/89)
# Plotting Wind Spd (km/h) for FORT ST. JOHN A (64/89)
# Plotting Wind Spd (km/h) for FORT ST JOHN A (65/89)
# Plotting Wind Spd (km/h) for FORT ST JAMES AUTO (66/89)
# Plotting Wind Spd (km/h) for FORT NELSON A (67/89)
# Plotting Wind Spd (km/h) for FORT NELSON (68/89)
# Plotting Wind Spd (km/h) for FANNY ISLAND (69/89)
# Plotting Wind Spd (km/h) for ESQUIMALT HARBOUR (70/89)
# Plotting Wind Spd (km/h) for ENTRANCE ISLAND (71/89)
# Plotting Wind Spd (km/h) for DISCOVERY ISLAND (72/89)
# Plotting Wind Spd (km/h) for DELTA BURNS BOG (73/89)
# Plotting Wind Spd (km/h) for DEASE LAKE LWIS (74/89)
# Plotting Wind Spd (km/h) for DEASE LAKE A (75/89)
# Plotting Wind Spd (km/h) for DEASE LAKE (AUT) (76/89)
# Plotting Wind Spd (km/h) for CRESTON CAMPBELL SCIENTIFIC (77/89)
# Plotting Wind Spd (km/h) for CRANBROOK AIRPORT AUTO (78/89)
# Plotting Wind Spd (km/h) for CRANBROOK A (79/89)
# Plotting Wind Spd (km/h) for COMOX A (80/89)
# Plotting Wind Spd (km/h) for CLINTON A (81/89)
# Plotting Wind Spd (km/h) for CLEARWATER AUTO (82/89)
# Plotting Wind Spd (km/h) for CALLAGHAN VALLEY (83/89)
# Plotting Wind Spd (km/h) for BURNS LAKE DECKER LAKE (84/89)
# Plotting Wind Spd (km/h) for BLUE RIVER CS (85/89)
# Plotting Wind Spd (km/h) for BALLENAS ISLAND (86/89)
# Plotting Wind Spd (km/h) for ASHCROFT (87/89)
# Plotting Wind Spd (km/h) for AGASSIZ RCS (88/89)
# Plotting Wind Spd (km/h) for ABBOTSFORD A (89/89)

# %%
# fig, axes = plt.subplots(ncols=1, nrows=len(WS_coverage_dict.keys()), figsize=(15, 25), sharex=True, dpi=200)
# plt.subplots_adjust(hspace=0)
# for i,ax in enumerate(axes):
#     print(f"Plotting {i+1}/{len(WS_coverage_dict.keys())}")
#     ax.set_xticks(
#         ticks=pd.date_range(start='1990-01-01', end='2026-01-01', freq='2YS'),
#         labels=[str(y.year) for y in pd.date_range(start='1990-01-01', end='2026-01-01', freq='2YS')],
#         rotation=45,
#         fontsize=8
#     )
#     ax.set_yticks(np.arange(0,80,20))
#     ax.grid(True, alpha=.2, linestyle='--')
#     stn = sorted(list(WS_coverage_dict.keys()), reverse=True)[i]
#     stn_data = get_stn(stn)
#     stn_data_rolling = stn_data['Wind Spd (km/h)'].rolling(window=24*30*1, center=True, min_periods=24*10).mean()
#     ax.plot(stn_data.index, stn_data["Wind Spd (km/h)"], label="Hourly", color="navy", lw=.7)
#     ax.plot(stn_data_rolling.index, stn_data_rolling, label=f"60-day Rolling Ave.", color="orange", lw=1.)
#     ax.text(0.005, 0.95, stn, transform=ax.transAxes, fontsize=8, color='red', ha='left', va='top')
#     if i == 0:
#         ax.legend(loc='upper right', fontsize=8, ncol=2, frameon=False)
#     if i < len(WS_coverage_dict.keys()) - 1:
#         ax.set_xticklabels([])
# plt.show()
